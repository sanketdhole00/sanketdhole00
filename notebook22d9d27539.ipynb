# %%
import pandas as pd
import numpy as np 
import string 
import spacy

# %%
Train00 = pd.read_csv("../input/task00/train.txt",sep=";",error_bad_lines=False)
Test00 = pd.read_csv("../input/task00/test.txt",sep=";",error_bad_lines=False)
Val00 = pd.read_csv("../input/task00/val.txt",sep=";",error_bad_lines=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Train00.columns=['Sentence','Mood']
Test00.columns=['Sentence','Mood']
Val00.columns=['Sentence','Mood']

# %%
Train00.head()
# Out:
#                                             Sentence     Mood
# 0  i can go from feeling so hopeless to so damned...  sadness
# 1   im grabbing a minute to post i feel greedy wrong    anger
# 2  i am ever feeling nostalgic about the fireplac...     love
# 3                               i am feeling grouchy    anger
# 4  ive been feeling a little burdened lately wasn...  sadness

# %%
print(Train00.info())
print(Test00.info())
print(Val00.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15999 entries, 0 to 15998
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  15999 non-null  object
#  1   Mood      15999 non-null  object
# dtypes: object(2)
# memory usage: 250.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  1999 non-null   object
#  1   Mood      1999 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  1999 non-null   object
#  1   Mood      1999 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB
# None

# %%
## checking is there any null value
print("Train=\n",Train00.isnull().sum())
print("Test=\n",Test00.isnull().sum())
print("Val =\n",Val00.isnull().sum())
# Out:
# Train=
#  Sentence    0
# Mood        0
# dtype: int64
# Test=
#  Sentence    0
# Mood        0
# dtype: int64
# Val =
#  Sentence    0
# Mood        0
# dtype: int64

# %%
Train00.Sentence[93]
# Out:
# 'i talk to dogs as i feel they cannot understand words but they can read emotions and know how to be supportive i decided i should go home'

# %%
from textblob import TextBlob

# %%
## splitting the data
x_train = Train00.iloc[:,0]
y_train = Train00.iloc[:,1]
x_test = Test00.iloc[:,0]
y_test = Test00.iloc[:,1]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
for i in [0.01,0.05,0.25,0.5,1]:
    model=LogisticRegression(C=i)
    model.fit(x_train,y_train)
    print("Accurracy for C=%f :%f"%(c,accuracy_score(model.predict(x_test))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_43/1611011189.py in <module>
#       1 for i in [0.01,0.05,0.25,0.5,1]:
#       2     model=LogisticRegression(C=i)
# ----> 3     model.fit(x_train,y_train)
#       4
#
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
# -> 1344                                    accept_large_sparse=solver != 'liblinear')
#    1345         check_classification_targets(y)
#    1346         self.classes_ = np.unique(y)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
# ...
